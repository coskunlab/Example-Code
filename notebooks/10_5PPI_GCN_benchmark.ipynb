# %% [markdown]
# # Test torch geometric

# %%
import os 
import networkx as nx 
import pickle 
import torch_geometric 

data_dir = r'Y:\coskun-lab\Thomas\23_PLA_revision\data\9PPI\graphs\raw'

# %%
for f in os.listdir(data_dir):
    with open(os.path.join(data_dir, f), 'rb') as file:
        G = pickle.load(file)
    data = torch_geometric.utils.from_networkx(G)
    break
# Out:
# c:\Users\thu71\AppData\Local\anaconda3\envs\scanpy\Lib\site-packages\torch_geometric\utils\convert.py:249: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ..\torch\csrc\utils\tensor_new.cpp:264.)
#   data[key] = torch.tensor(value)

# %%
import wandb

# %% [markdown]
# # Loop code

# %%
import os
import sys
from pathlib import Path

import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import skimage.io

from collections import defaultdict
from tqdm.auto import tqdm
from joblib import Parallel, delayed
import re
import tifffile as tiff
import pickle

import networkx as nx
from sklearn.model_selection import train_test_split

# %%
import torch_geometric.utils
import torch

# %%
# %load_ext autoreload
# %autoreload 2

# %%
p_dir = (Path().cwd().parents[0]).absolute()

module_path = str(p_dir / "src")

if module_path not in sys.path:
    sys.path.append(module_path)

# %%
data_dir = (Path().cwd().parents[0] / 'data').absolute()

# %%
import lightning.pytorch as pl
import PPIGraph
# Out:
# c:\Users\thu71\AppData\Local\anaconda3\envs\scanpy\Lib\site-packages\torchvision\io\image.py:13: UserWarning: Failed to load image Python extension: '[WinError 127] The specified procedure could not be found'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(

# %% [markdown]
# # Load dataset

# %%
from torch_geometric.loader import DataLoader

# Define condition mapping
condition_mapping = {'HCC827Ctrl': 0, 'HCC827Osim': 1}

# Load graph dataset and process if neede
graph_path = data_dir / 'OCT Cell Culture' / 'Whole' / 'graphs' 

dataset = PPIGraph.GraphDataset(graph_path, 'raw', 'pt', condition_mapping=condition_mapping, n_c=2)
train_set, val_set, test_set = PPIGraph.train_test_val_split(dataset)

# Create Dataloader
train_loader = DataLoader(train_set, batch_size=32, shuffle=True)
val_loader = DataLoader(val_set, batch_size=32, shuffle=True)
test_loader = DataLoader(test_set, batch_size=32, shuffle=False)

# %%
# Print some information on the dataset
print(f'Dataset: {dataset}:')
print('======================')
print(f'Number of graphs: {len(dataset)}')
print(f'Number of features: {dataset.num_features}')
print(f'Number of classes: {dataset.num_classes}')

print(f'Train set: {len(train_set)}, test set: {len(test_set)}, val set: {len(val_set)}')
for step, data in enumerate(train_loader):

    print(f'Step {step + 1}:')
    print('=======')
    print(f'Number of graphs in the current batch: {data.num_graphs}')
    print(data)
    print()
    break
# Out:
# Dataset: GraphDataset(2064):
# ======================
# Number of graphs: 2064
# Number of features: 5
# Number of classes: 2
# Train set: 992, test set: 825, val set: 247
# Step 1:
# =======
# Number of graphs in the current batch: 32
# DataBatch(edge_index=[2, 15262], pos=[2906, 2], labels=[2906, 5], nuclei=[2906], weight=[15262], condition=[32], fov=[32], id=[32], train_mask=[2906], test_mask=[2906], edge_attr=[15262, 2], x=[2906, 5], y=[32], edge_weight=[15262], name=[32], batch=[2906], ptr=[33])

# %% [markdown]
# # K-fold on filter dataset

# %%
import itertools
from lightning.pytorch.accelerators import find_usable_cuda_devices
import wandb

# %%
from sklearn.model_selection import KFold, StratifiedKFold
from torch.utils.data import SubsetRandomSampler

# %%
# Filter out by maximum number of counts per cell
min_count = 20
max_count = 70

graph_path = data_dir / 'OCT Cell Culture' / 'Whole' / 'graphs' 
dataset = PPIGraph.GraphDataset(graph_path, 'raw', 'pt', condition_mapping=condition_mapping, n_c=2)

# Create Dataloader
loader = DataLoader(dataset, batch_size=1, shuffle=False)

# Get Indices
indices = []
for step, data in enumerate(loader):
    if len(data.x) <= min_count:
        continue 
    
    if (data.x.sum(axis=0) >= max_count).any():
        continue
    indices.append(step)
    
# Get subset dataset
dataset_filtered = dataset.index_select(indices)

# %%
len(dataset_filtered)
# Out:
# 1522

# %%
dataset_name = '5PPI'
condition = 'Kfold'
checkpoint_folder = (Path().cwd().parents[0]).absolute() / 'data' /'OCT Cell Culture' / 'Whole' /"saved_models" / dataset_name / f"Graph_GNNs_{condition}" 
project_name = f'PLA_01102024_{dataset_name}_{condition}'

# %%
AVAIL_GPUS = [0]

# Setting the seed
pl.seed_everything(42)

NUM_LAYERS = 2
HIDDEN_CHANNELS = 16
pools = ['mean', 'max', 'sum', 'attention', 'attention2']
num_layers = [2,3,4]
hiddens = [16, 32, 64]

epochs = 50
models = ['GCN', 'GraphConv']
# Out:
# Global seed set to 42

# %%
k_folds = 5
kfold = KFold(n_splits=k_folds, shuffle=True, random_state=42)

for fold, (train_ids, valid_ids) in enumerate(kfold.split(dataset_filtered)):
    train_subset = dataset_filtered.index_select(train_ids.tolist())
    val_subset = dataset_filtered.index_select(valid_ids.tolist())
    for NUM_LAYERS, HIDDEN_CHANNELS, pool, model in list(itertools.product(*[num_layers, hiddens, pools, models])):
            # Path to the folder where the pretrained models are saved
        CHECKPOINT_PATH = checkpoint_folder / f'{model}_{NUM_LAYERS}_{HIDDEN_CHANNELS}_onehot_{fold}' / pool
        CHECKPOINT_PATH.mkdir(parents=True, exist_ok=True)

        # Skip already trained kfold and pool
        checkpoint = CHECKPOINT_PATH / f"GraphLevel{model}" / f"GraphLevel{model}.ckpt" 
        if checkpoint.exists():
            print(checkpoint)
            continue

        # Run training
        run = wandb.init(project=project_name, name=f'{model}_{NUM_LAYERS}_{HIDDEN_CHANNELS}_onehot_{fold}', 
                        group=f'{model}_{pool}', 
                        # mode="disabled"
                        )
        PPIGraph.train_graph_classifier_kfold(model, 
                                                train_subset, 
                                                val_subset, 
                                                dataset, 
                                                CHECKPOINT_PATH, 
                                                AVAIL_GPUS, 
                                                in_channels=5,
                                                hidden_channels=HIDDEN_CHANNELS, 
                                                out_channels = HIDDEN_CHANNELS,
                                                num_layers=NUM_LAYERS, 
                                                epochs=epochs,
                                                embedding=False,
                                                batch_size=256, 
                                                graph_pooling=pool)
        run.finish()
# Out:
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_2_16_onehot_0\mean\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_2_16_onehot_0\mean\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_2_16_onehot_0\max\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_2_16_onehot_0\max\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_2_16_onehot_0\sum\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_2_16_onehot_0\sum\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_2_16_onehot_0\attention\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_2_16_onehot_0\attention\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_2_16_onehot_0\attention2\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_2_16_onehot_0\attention2\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_2_32_onehot_0\mean\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_2_32_onehot_0\mean\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_2_32_onehot_0\max\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_2_32_onehot_0\max\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_2_32_onehot_0\sum\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_2_32_onehot_0\sum\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_2_32_onehot_0\attention\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_2_32_onehot_0\attention\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_2_32_onehot_0\attention2\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_2_32_onehot_0\attention2\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_2_64_onehot_0\mean\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_2_64_onehot_0\mean\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_2_64_onehot_0\max\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_2_64_onehot_0\max\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_2_64_onehot_0\sum\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_2_64_onehot_0\sum\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_2_64_onehot_0\attention\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_2_64_onehot_0\attention\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_2_64_onehot_0\attention2\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_2_64_onehot_0\attention2\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_3_16_onehot_0\mean\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_3_16_onehot_0\mean\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_3_16_onehot_0\max\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_3_16_onehot_0\max\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_3_16_onehot_0\sum\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_3_16_onehot_0\sum\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_3_16_onehot_0\attention\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_3_16_onehot_0\attention\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_3_16_onehot_0\attention2\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_3_16_onehot_0\attention2\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_3_32_onehot_0\mean\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_3_32_onehot_0\mean\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_3_32_onehot_0\max\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_3_32_onehot_0\max\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_3_32_onehot_0\sum\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_3_32_onehot_0\sum\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_3_32_onehot_0\attention\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_3_32_onehot_0\attention\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_3_32_onehot_0\attention2\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_3_32_onehot_0\attention2\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_3_64_onehot_0\mean\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_3_64_onehot_0\mean\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_3_64_onehot_0\max\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_3_64_onehot_0\max\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_3_64_onehot_0\sum\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_3_64_onehot_0\sum\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_3_64_onehot_0\attention\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_3_64_onehot_0\attention\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_3_64_onehot_0\attention2\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_3_64_onehot_0\attention2\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_4_16_onehot_0\mean\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_4_16_onehot_0\mean\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_4_16_onehot_0\max\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_4_16_onehot_0\max\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_4_16_onehot_0\sum\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_4_16_onehot_0\sum\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_4_16_onehot_0\attention\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_4_16_onehot_0\attention\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_4_16_onehot_0\attention2\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_4_16_onehot_0\attention2\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_4_32_onehot_0\mean\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_4_32_onehot_0\mean\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_4_32_onehot_0\max\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_4_32_onehot_0\max\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_4_32_onehot_0\sum\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_4_32_onehot_0\sum\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_4_32_onehot_0\attention\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_4_32_onehot_0\attention\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_4_32_onehot_0\attention2\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_4_32_onehot_0\attention2\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_4_64_onehot_0\mean\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_4_64_onehot_0\mean\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_4_64_onehot_0\max\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_4_64_onehot_0\max\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_4_64_onehot_0\sum\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_4_64_onehot_0\sum\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_4_64_onehot_0\attention\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_4_64_onehot_0\attention\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_4_64_onehot_0\attention2\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_4_64_onehot_0\attention2\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_2_16_onehot_1\mean\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_2_16_onehot_1\mean\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_2_16_onehot_1\max\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_2_16_onehot_1\max\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_2_16_onehot_1\sum\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_2_16_onehot_1\sum\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_2_16_onehot_1\attention\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_2_16_onehot_1\attention\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_2_16_onehot_1\attention2\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_2_16_onehot_1\attention2\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_2_32_onehot_1\mean\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_2_32_onehot_1\mean\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_2_32_onehot_1\max\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_2_32_onehot_1\max\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_2_32_onehot_1\sum\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_2_32_onehot_1\sum\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_2_32_onehot_1\attention\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_2_32_onehot_1\attention\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_2_32_onehot_1\attention2\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_2_32_onehot_1\attention2\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_2_64_onehot_1\mean\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_2_64_onehot_1\mean\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_2_64_onehot_1\max\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_2_64_onehot_1\max\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_2_64_onehot_1\sum\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_2_64_onehot_1\sum\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_2_64_onehot_1\attention\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_2_64_onehot_1\attention\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_2_64_onehot_1\attention2\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_2_64_onehot_1\attention2\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_3_16_onehot_1\mean\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_3_16_onehot_1\mean\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_3_16_onehot_1\max\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_3_16_onehot_1\max\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_3_16_onehot_1\sum\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_3_16_onehot_1\sum\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_3_16_onehot_1\attention\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_3_16_onehot_1\attention\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_3_16_onehot_1\attention2\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_3_16_onehot_1\attention2\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_3_32_onehot_1\mean\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_3_32_onehot_1\mean\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_3_32_onehot_1\max\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_3_32_onehot_1\max\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_3_32_onehot_1\sum\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_3_32_onehot_1\sum\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_3_32_onehot_1\attention\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_3_32_onehot_1\attention\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_3_32_onehot_1\attention2\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_3_32_onehot_1\attention2\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_3_64_onehot_1\mean\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_3_64_onehot_1\mean\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_3_64_onehot_1\max\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_3_64_onehot_1\max\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_3_64_onehot_1\sum\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_3_64_onehot_1\sum\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_3_64_onehot_1\attention\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_3_64_onehot_1\attention\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_3_64_onehot_1\attention2\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_3_64_onehot_1\attention2\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_4_16_onehot_1\mean\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_4_16_onehot_1\mean\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_4_16_onehot_1\max\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_4_16_onehot_1\max\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_4_16_onehot_1\sum\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_4_16_onehot_1\sum\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_4_16_onehot_1\attention\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_4_16_onehot_1\attention\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_4_16_onehot_1\attention2\GraphLevelGCN\GraphLevelGCN.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_4_16_onehot_1\attention2\GraphLevelGraphConv\GraphLevelGraphConv.ckpt
# y:\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_4_32_onehot_1\mean\GraphLevelGCN\GraphLevelGCN.ckpt
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: thoomas. Use `wandb login --relogin` to force relogin
# wandb version 0.16.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.8
# Run data is saved locally in <code>y:\coskun-lab\Thomas\23_PLA_revision\notebooks\wandb\run-20240111_175355-pdvk0ypc</code>
# Syncing run <strong><a href='https://wandb.ai/thoomas/PLA_01102024_5PPI_Kfold/runs/pdvk0ypc' target="_blank">GraphConv_4_32_onehot_1</a></strong> to <a href='https://wandb.ai/thoomas/PLA_01102024_5PPI_Kfold' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/thoomas/PLA_01102024_5PPI_Kfold' target="_blank">https://wandb.ai/thoomas/PLA_01102024_5PPI_Kfold</a>
#  View run at <a href='https://wandb.ai/thoomas/PLA_01102024_5PPI_Kfold/runs/pdvk0ypc' target="_blank">https://wandb.ai/thoomas/PLA_01102024_5PPI_Kfold/runs/pdvk0ypc</a>
# Global seed set to 42
# c:\Users\thu71\AppData\Local\anaconda3\envs\scanpy\Lib\site-packages\pytorch_lightning\loggers\wandb.py:397: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Global seed set to 42
# Using GNN
# You are using a CUDA device ('NVIDIA RTX A2000 12GB') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# c:\Users\thu71\AppData\Local\anaconda3\envs\scanpy\Lib\site-packages\lightning\pytorch\callbacks\model_checkpoint.py:617: UserWarning: Checkpoint directory \\bme-retromaster.ad.gatech.edu\labs5\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_4_32_onehot_1\mean\GraphLevelGraphConv exists and is not empty.
#   rank_zero_warn(f"Checkpoint directory {dirpath} exists and is not empty.")
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name        | Type             | Params
# -------------------------------------------------
# 0 | x_embedding | Identity         | 0
# 1 | model       | GNNModel         | 6.8 K
# 2 | head        | Sequential       | 562
# 3 | loss_module | CrossEntropyLoss | 0
# 4 | train_acc   | BinaryAccuracy   | 0
# 5 | train_auroc | BinaryAUROC      | 0
# 6 | train_f1    | BinaryF1Score    | 0
# 7 | valid_acc   | BinaryAccuracy   | 0
# 8 | valid_auroc | BinaryAUROC      | 0
# 9 | valid_f1    | BinaryF1Score    | 0
# -------------------------------------------------
# 7.3 K     Trainable params
# 0         Non-trainable params
# 7.3 K     Total params
# 0.029     Total estimated model params size (MB)
# c:\Users\thu71\AppData\Local\anaconda3\envs\scanpy\Lib\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:486: PossibleUserWarning: Your `val_dataloader`'s sampler has shuffling enabled, it is strongly recommended that you turn shuffling off for val/test dataloaders.
#   rank_zero_warn(
# c:\Users\thu71\AppData\Local\anaconda3\envs\scanpy\Lib\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:438: PossibleUserWarning: The dataloader, val_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# c:\Users\thu71\AppData\Local\anaconda3\envs\scanpy\Lib\site-packages\lightning\pytorch\utilities\data.py:76: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# c:\Users\thu71\AppData\Local\anaconda3\envs\scanpy\Lib\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:438: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# c:\Users\thu71\AppData\Local\anaconda3\envs\scanpy\Lib\site-packages\lightning\pytorch\loops\fit_loop.py:281: PossibleUserWarning: The number of training batches (5) is smaller than the logging interval Trainer(log_every_n_steps=10). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   rank_zero_warn(
# `Trainer.fit` stopped: `max_epochs=50` reached.
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>lr-Adam</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_acc</td><td>▁
td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">GraphConv_4_32_onehot_1</strong> at: <a href='https://wandb.ai/thoomas/PLA_01102024_5PPI_Kfold/runs/wyxx2791' target="_blank">https://wandb.ai/thoomas/PLA_01102024_5PPI_Kfold/runs/wyxx2791</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240111_180911-wyxx2791\logs</code>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016933333330477276, max=1.0…
# wandb version 0.16.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.8
# Run data is saved locally in <code>y:\coskun-lab\Thomas\23_PLA_revision\notebooks\wandb\run-20240111_181740-4s8xa1mr</code>
# Syncing run <strong><a href='https://wandb.ai/thoomas/PLA_01102024_5PPI_Kfold/runs/4s8xa1mr' target="_blank">GCN_4_32_onehot_1</a></strong> to <a href='https://wandb.ai/thoomas/PLA_01102024_5PPI_Kfold' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/thoomas/PLA_01102024_5PPI_Kfold' target="_blank">https://wandb.ai/thoomas/PLA_01102024_5PPI_Kfold</a>
#  View run at <a href='https://wandb.ai/thoomas/PLA_01102024_5PPI_Kfold/runs/4s8xa1mr' target="_blank">https://wandb.ai/thoomas/PLA_01102024_5PPI_Kfold/runs/4s8xa1mr</a>
# Global seed set to 42
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Global seed set to 42
# c:\Users\thu71\AppData\Local\anaconda3\envs\scanpy\Lib\site-packages\lightning\pytorch\callbacks\model_checkpoint.py:617: UserWarning: Checkpoint directory \\bme-retromaster.ad.gatech.edu\labs5\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_4_32_onehot_1\sum\GraphLevelGCN exists and is not empty.
#   rank_zero_warn(f"Checkpoint directory {dirpath} exists and is not empty.")
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name        | Type             | Params
# -------------------------------------------------
# 0 | x_embedding | Identity         | 0
# 1 | model       | GNNModel         | 3.6 K
# 2 | head        | Sequential       | 562
# 3 | loss_module | CrossEntropyLoss | 0
# 4 | train_acc   | BinaryAccuracy   | 0
# 5 | train_auroc | BinaryAUROC      | 0
# 6 | train_f1    | BinaryF1Score    | 0
# 7 | valid_acc   | BinaryAccuracy   | 0
# 8 | valid_auroc | BinaryAUROC      | 0
# 9 | valid_f1    | BinaryF1Score    | 0
# -------------------------------------------------
# 4.1 K     Trainable params
# 0         Non-trainable params
# 4.1 K     Total params
# 0.016     Total estimated model params size (MB)
# Using GNN
# `Trainer.fit` stopped: `max_epochs=50` reached.
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# ...
#  View run <strong style="color:#cdcd00">GCN_4_64_onehot_4</strong> at: <a href='https://wandb.ai/thoomas/PLA_01102024_5PPI_Kfold/runs/t05kp62k' target="_blank">https://wandb.ai/thoomas/PLA_01102024_5PPI_Kfold/runs/t05kp62k</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240113_131019-t05kp62k\logs</code>
# wandb version 0.16.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.8
# Run data is saved locally in <code>y:\coskun-lab\Thomas\23_PLA_revision\notebooks\wandb\run-20240113_132102-wbu1cehb</code>
# Syncing run <strong><a href='https://wandb.ai/thoomas/PLA_01102024_5PPI_Kfold/runs/wbu1cehb' target="_blank">GraphConv_4_64_onehot_4</a></strong> to <a href='https://wandb.ai/thoomas/PLA_01102024_5PPI_Kfold' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/thoomas/PLA_01102024_5PPI_Kfold' target="_blank">https://wandb.ai/thoomas/PLA_01102024_5PPI_Kfold</a>
#  View run at <a href='https://wandb.ai/thoomas/PLA_01102024_5PPI_Kfold/runs/wbu1cehb' target="_blank">https://wandb.ai/thoomas/PLA_01102024_5PPI_Kfold/runs/wbu1cehb</a>
# Global seed set to 42
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Global seed set to 42
# c:\Users\thu71\AppData\Local\anaconda3\envs\scanpy\Lib\site-packages\lightning\pytorch\callbacks\model_checkpoint.py:617: UserWarning: Checkpoint directory \\bme-retromaster.ad.gatech.edu\labs5\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_4_64_onehot_4\attention\GraphLevelGraphConv exists and is not empty.
#   rank_zero_warn(f"Checkpoint directory {dirpath} exists and is not empty.")
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#    | Name        | Type             | Params
# --------------------------------------------------
# 0  | x_embedding | Identity         | 0
# 1  | model       | GNNModel         | 25.9 K
# 2  | head        | Sequential       | 2.1 K
# 3  | loss_module | CrossEntropyLoss | 0
# 4  | train_acc   | BinaryAccuracy   | 0
# 5  | train_auroc | BinaryAUROC      | 0
# 6  | train_f1    | BinaryF1Score    | 0
# 7  | valid_acc   | BinaryAccuracy   | 0
# 8  | valid_auroc | BinaryAUROC      | 0
# 9  | valid_f1    | BinaryF1Score    | 0
# 10 | pool        | GlobalAttention  | 65
# --------------------------------------------------
# 28.1 K    Trainable params
# 0         Non-trainable params
# 28.1 K    Total params
# 0.112     Total estimated model params size (MB)
# Using GNN
# `Trainer.fit` stopped: `max_epochs=50` reached.
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>lr-Adam</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_acc</td><td>▁▄▄▅▆▇▆▇▇▇▇▇▇▇▇▇▇▇▇█▇██▇▇▇▇█▇▇▇█████▇▇██</td></tr><tr><td>train_auc</td><td>▁▄▅▅▆▇▇▇▇▇▇▇▇▇▇▇▇████████▇██▇▇██████████</td></tr><tr><td>train_f1</td><td>▁▂▄▅▆▆▇▇▇▆▇▇▇▆▇▇█▇█████▇█▆█▇▇▇██████▇██▇</td></tr><tr><td>train_loss_epoch</td><td>█▆▅▄▄▃▃▃▃▃▂▂▂▂▂▃▂▂▂▂▁▁▁▂▂▂▂▂▃▂▁▁▁▂▁▁▁▂▁▁</td></tr><tr><td>train_loss_step</td><td>█▆▆█▃▄▂▃▅▆▂▃▃▅▄▃▃▂▂▃▄▁▅▂▃</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▁▂▁▂▁▂▂▃▃▃▃▄▄▂▄▂▄▂▅▃▅▃▆▆▆▃▃▇▇▇▃▇▄█▄█▄</td></tr><tr><td>val_acc</td><td>▁▃▆▆▆▇▇▇▆██▆▇▇█████▇▇█▇█▆▇▆▇▇▇█▇▇▇█▇▇██▇</td></tr><tr><td>val_auc</td><td>▁▂▃▄▆▆▆▆▇▇▇▇▇▇▇▆▇▇▇▆▇▇▇██▇▇▇▇███▇▇█▇▇▇▇▇</td></tr><tr><td>val_f1</td><td>▁▃▆▇██████▇█▇█▇█▇▇▇▇▇█▇█▆▇▆██▇█▇█▇█▇████</td></tr><tr><td>val_loss_epoch</td><td>█▇▆▅▄▄▃▃▄▄▃▅▄▄▃▂▄▁▂▃▂▂▁▂▇▂▄▃▄▃▂▂▃▄▃▃▂▄▃▆</td></tr><tr><td>val_loss_step</td><td>█▇▇▆▆▅▄▄▆▅▅▆▄▆▅▄▄▂▃▅▄▃▁▅▆▃▅▄▆▄▄▄▅▆▅▅▃▅▅▆</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>49</td></tr><tr><td>lr-Adam</td><td>0.005</td></tr><tr><td>train_acc</td><td>0.79885</td></tr><tr><td>train_auc</td><td>0.8713</td></tr><tr><td>train_f1</td><td>0.69027</td></tr><tr><td>train_loss_epoch</td><td>0.43661</td></tr><tr><td>train_loss_step</td><td>0.44893</td></tr><tr><td>trainer/global_step</td><td>249</td></tr><tr><td>val_acc</td><td>0.72368</td></tr><tr><td>val_auc</td><td>0.82622</td></tr><tr><td>val_f1</td><td>0.72903</td></tr><tr><td>val_loss_epoch</td><td>0.6062</td></tr><tr><td>val_loss_step</td><td>0.60088</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">GraphConv_4_64_onehot_4</strong> at: <a href='https://wandb.ai/thoomas/PLA_01102024_5PPI_Kfold/runs/wbu1cehb' target="_blank">https://wandb.ai/thoomas/PLA_01102024_5PPI_Kfold/runs/wbu1cehb</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240113_132102-wbu1cehb\logs</code>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016933333330477276, max=1.0…
# wandb version 0.16.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.8
# Run data is saved locally in <code>y:\coskun-lab\Thomas\23_PLA_revision\notebooks\wandb\run-20240113_133027-b7q3bba7</code>
# Syncing run <strong><a href='https://wandb.ai/thoomas/PLA_01102024_5PPI_Kfold/runs/b7q3bba7' target="_blank">GCN_4_64_onehot_4</a></strong> to <a href='https://wandb.ai/thoomas/PLA_01102024_5PPI_Kfold' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/thoomas/PLA_01102024_5PPI_Kfold' target="_blank">https://wandb.ai/thoomas/PLA_01102024_5PPI_Kfold</a>
#  View run at <a href='https://wandb.ai/thoomas/PLA_01102024_5PPI_Kfold/runs/b7q3bba7' target="_blank">https://wandb.ai/thoomas/PLA_01102024_5PPI_Kfold/runs/b7q3bba7</a>
# Global seed set to 42
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Global seed set to 42
# c:\Users\thu71\AppData\Local\anaconda3\envs\scanpy\Lib\site-packages\lightning\pytorch\callbacks\model_checkpoint.py:617: UserWarning: Checkpoint directory \\bme-retromaster.ad.gatech.edu\labs5\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GCN_4_64_onehot_4\attention2\GraphLevelGCN exists and is not empty.
#   rank_zero_warn(f"Checkpoint directory {dirpath} exists and is not empty.")
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#    | Name        | Type             | Params
# --------------------------------------------------
# 0  | x_embedding | Identity         | 0
# 1  | model       | GNNModel         | 13.2 K
# 2  | head        | Sequential       | 2.1 K
# 3  | loss_module | CrossEntropyLoss | 0
# 4  | train_acc   | BinaryAccuracy   | 0
# 5  | train_auroc | BinaryAUROC      | 0
# 6  | train_f1    | BinaryF1Score    | 0
# 7  | valid_acc   | BinaryAccuracy   | 0
# 8  | valid_auroc | BinaryAUROC      | 0
# 9  | valid_f1    | BinaryF1Score    | 0
# 10 | pool        | Attention_module | 4.2 K
# --------------------------------------------------
# 19.6 K    Trainable params
# 0         Non-trainable params
# 19.6 K    Total params
# 0.078     Total estimated model params size (MB)
# Using GNN
# `Trainer.fit` stopped: `max_epochs=50` reached.
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>lr-Adam</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_acc</td><td>▁▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇█▇█▇▇▇█▇▇▇██▇▇████▇</td></tr><tr><td>train_auc</td><td>▁▆▇▇▇▇▇▇███▇▇▇▇▇█████▇████▇███▇█████████</td></tr><tr><td>train_f1</td><td>▁▆▇██▇▇████▇██▇█▇▇█▇█████▇▇██▇▇████████▇</td></tr><tr><td>train_loss_epoch</td><td>█▄▃▂▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▂▂▂▂▂▂▁▂▂▂▂▁▂▂▂▁▁▁▂</td></tr><tr><td>train_loss_step</td><td>▆▄▄▃▄█▅▃▇▅▅▁▂▃▅▂▄▃▄▂▆▆▁▂▄</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▁▂▁▂▁▂▂▃▃▃▃▄▄▂▄▂▄▂▅▃▅▃▆▆▆▃▃▇▇▇▃▇▄█▄█▄</td></tr><tr><td>val_acc</td><td>▁▁▁▁▁▁▁▂▂▄▅▅▅▅▇▆█▇▆▆▆▆▇▇▇▇█▇█▇▇▇▇███▇█▇▇</td></tr><tr><td>val_auc</td><td>▁▄▂▄▄▅▄▅▇▆▇▇▇▇▅▅▆▇█▇▇▇▆▅▇▆▇▆▆▅▇█▇█▇▆▇▇▇▄</td></tr><tr><td>val_f1</td><td>▁▁▁▁▁▁▁▂▂▄▄▅▅▅▇▆▇▇▆▆▅▆▇▇▇▇█▇▇▅▇▇▇██▇▇█▇▆</td></tr><tr><td>val_loss_epoch</td><td>▂▅███▆▆▃▄▂▂▂▃▂▁▂▁▁▂▂▂▂▁▁▂▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss_step</td><td>▃▆█▇█▇▆▃▄▃▂▂▂▂▁▁▁▁▂▂▂▂▂▂▂▁▂▂▁▂▂▂▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>49</td></tr><tr><td>lr-Adam</td><td>0.005</td></tr><tr><td>train_acc</td><td>0.78325</td></tr><tr><td>train_auc</td><td>0.85828</td></tr><tr><td>train_f1</td><td>0.65535</td></tr><tr><td>train_loss_epoch</td><td>0.4481</td></tr><tr><td>train_loss_step</td><td>0.46506</td></tr><tr><td>trainer/global_step</td><td>249</td></tr><tr><td>val_acc</td><td>0.73684</td></tr><tr><td>val_auc</td><td>0.82414</td></tr><tr><td>val_f1</td><td>0.70588</td></tr><tr><td>val_loss_epoch</td><td>0.49761</td></tr><tr><td>val_loss_step</td><td>0.47743</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">GCN_4_64_onehot_4</strong> at: <a href='https://wandb.ai/thoomas/PLA_01102024_5PPI_Kfold/runs/b7q3bba7' target="_blank">https://wandb.ai/thoomas/PLA_01102024_5PPI_Kfold/runs/b7q3bba7</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240113_133027-b7q3bba7\logs</code>
# wandb version 0.16.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.8
# Run data is saved locally in <code>y:\coskun-lab\Thomas\23_PLA_revision\notebooks\wandb\run-20240113_134056-a1dm0ry5</code>
# Syncing run <strong><a href='https://wandb.ai/thoomas/PLA_01102024_5PPI_Kfold/runs/a1dm0ry5' target="_blank">GraphConv_4_64_onehot_4</a></strong> to <a href='https://wandb.ai/thoomas/PLA_01102024_5PPI_Kfold' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/thoomas/PLA_01102024_5PPI_Kfold' target="_blank">https://wandb.ai/thoomas/PLA_01102024_5PPI_Kfold</a>
#  View run at <a href='https://wandb.ai/thoomas/PLA_01102024_5PPI_Kfold/runs/a1dm0ry5' target="_blank">https://wandb.ai/thoomas/PLA_01102024_5PPI_Kfold/runs/a1dm0ry5</a>
# Global seed set to 42
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Global seed set to 42
# c:\Users\thu71\AppData\Local\anaconda3\envs\scanpy\Lib\site-packages\lightning\pytorch\callbacks\model_checkpoint.py:617: UserWarning: Checkpoint directory \\bme-retromaster.ad.gatech.edu\labs5\coskun-lab\Thomas\23_PLA_revision\data\OCT Cell Culture\Whole\saved_models\5PPI\Graph_GNNs_Kfold\GraphConv_4_64_onehot_4\attention2\GraphLevelGraphConv exists and is not empty.
#   rank_zero_warn(f"Checkpoint directory {dirpath} exists and is not empty.")
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#    | Name        | Type             | Params
# --------------------------------------------------
# 0  | x_embedding | Identity         | 0
# 1  | model       | GNNModel         | 25.9 K
# 2  | head        | Sequential       | 2.1 K
# 3  | loss_module | CrossEntropyLoss | 0
# 4  | train_acc   | BinaryAccuracy   | 0
# 5  | train_auroc | BinaryAUROC      | 0
# 6  | train_f1    | BinaryF1Score    | 0
# 7  | valid_acc   | BinaryAccuracy   | 0
# 8  | valid_auroc | BinaryAUROC      | 0
# 9  | valid_f1    | BinaryF1Score    | 0
# 10 | pool        | Attention_module | 4.2 K
# --------------------------------------------------
# 32.2 K    Trainable params
# 0         Non-trainable params
# 32.2 K    Total params
# 0.129     Total estimated model params size (MB)
# Using GNN
# `Trainer.fit` stopped: `max_epochs=50` reached.
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>lr-Adam</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_acc</td><td>▁▃▄▄▆▆▆▆▆▇▆▇▇▇▇▇▇▇▆▇▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇█▇▇▇▇</td></tr><tr><td>train_auc</td><td>▁▃▄▄▆▆▇▇▇▇▇▇▇▇▇▇██▇▇▇▇▇██████▇██████▇███</td></tr><tr><td>train_f1</td><td>▁▁▃▄▇▆▆▆▇▇▇▇▇▇▇▇█▇▇▇▇█▇▇▇▇█▇█▇███▇▇█▇█▇▇</td></tr><tr><td>train_loss_epoch</td><td>█▇▆▆▄▃▃▃▃▃▂▂▂▂▂▂▂▂▃▂▂▂▂▂▂▂▂▂▂▂▂▂▁▂▂▁▂▂▁▂</td></tr><tr><td>train_loss_step</td><td>▇█▆▄▄▄▃▃▃▃▄▄▃▂▁▂▃▁▂▄▅▁▃▃▄</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▁▂▁▂▁▂▂▃▃▃▃▄▄▂▄▂▄▂▅▃▅▃▆▆▆▃▃▇▇▇▃▇▄█▄█▄</td></tr><tr><td>val_acc</td><td>▁▁▇▇▇▆▆▇▇▇█▇█▇▇▇▇█▇▇▇▇▇█▇▇█▇▇▇▆▇█▇▆▇▇▆▇▇</td></tr><tr><td>val_auc</td><td>▁▃▅▆▇▆▇▇▇▇▇▇▇▇▇███████▇█▇▇████▇▇▇▇▇█▇▇█▇</td></tr><tr><td>val_f1</td><td>▁▁▆██▇████▇▇▇▇▇█▇█▇█▇▇███▇██▇█▆▇█▇▆▇█▅▇▇</td></tr><tr><td>val_loss_epoch</td><td>▇█▇▅▅▅▆▄▄▃▂▄▁▂▅▄▄▁▂▄▃▅▅▃▄▄▃▄▅▃▄▆▅▅▇▂▃▇▂▅</td></tr><tr><td>val_loss_step</td><td>█▇▇▆▅▅▆▅▅▅▃▄▅▂▆▄▄▁▂▅▄▇▇▅▄▄▅▅▆▄▄▅▆▆▅▇▄▆▆▆</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>49</td></tr><tr><td>lr-Adam</td><td>0.005</td></tr><tr><td>train_acc</td><td>0.79146</td></tr><tr><td>train_auc</td><td>0.87544</td></tr><tr><td>train_f1</td><td>0.66402</td></tr><tr><td>train_loss_epoch</td><td>0.42922</td></tr><tr><td>train_loss_step</td><td>0.47023</td></tr><tr><td>trainer/global_step</td><td>249</td></tr><tr><td>val_acc</td><td>0.73684</td></tr><tr><td>val_auc</td><td>0.8388</td></tr><tr><td>val_f1</td><td>0.62617</td></tr><tr><td>val_loss_epoch</td><td>0.53886</td></tr><tr><td>val_loss_step</td><td>0.56199</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">GraphConv_4_64_onehot_4</strong> at: <a href='https://wandb.ai/thoomas/PLA_01102024_5PPI_Kfold/runs/a1dm0ry5' target="_blank">https://wandb.ai/thoomas/PLA_01102024_5PPI_Kfold/runs/a1dm0ry5</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240113_134056-a1dm0ry5\logs</code>
